# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
file_path = "2324.csv"

prem_data = pd.read_csv(file_path)

# %%
prem_data.head()
# Out:
#   Div        Date   Time     HomeTeam       AwayTeam  FTHG  FTAG FTR  HTHG  \
# 0  E0  11/08/2023  20:00      Burnley       Man City     0     3   A     0
# 1  E0  12/08/2023  12:30      Arsenal  Nott'm Forest     2     1   H     2
# 2  E0  12/08/2023  15:00  Bournemouth       West Ham     1     1   D     0
# 3  E0  12/08/2023  15:00     Brighton          Luton     4     1   H     1
# 4  E0  12/08/2023  15:00      Everton         Fulham     0     1   A     0
#
#    HTAG  ... AvgC<2.5  AHCh  B365CAHH  B365CAHA  PCAHH  PCAHA  MaxCAHH  \
# 0     2  ...     2.28  1.50      1.95      1.98   1.95   1.97      NaN
# 1     0  ...     2.63 -2.00      1.95      1.98   1.93   1.97     2.01
# 2     0  ...     2.12  0.00      2.02      1.91   2.01   1.92     2.06
# 3     0  ...     2.48 -1.75      2.01      1.92   2.00   1.91     2.14
# 4     0  ...     1.71 -0.25      2.06      1.87   2.04   1.88     2.08
#
#    MaxCAHA  AvgCAHH  AvgCAHA
# 0      NaN     1.92     1.95
# ...

# %%
prem_data['HS'].mean()
# Out:
# np.float64(15.402631578947368)

# %%
prem_data['AS'].mean()
# Out:
# np.float64(12.18157894736842)

# %%
prem_data['HF'].mean()
# Out:
# np.float64(10.744736842105263)

# %%
prem_data['AF'].mean()
# Out:
# np.float64(11.347368421052632)

# %%
prem_data['HS'].plot(kind='kde', figsize=(14, 6))
# Out:
# <Axes: ylabel='Density'>

# %%
prem_data['HS'].plot(kind='box', vert=False, figsize=(14, 6))
# Out:
# <Axes: >

# %%
prem_data['HS'].plot(kind='hist', bins=10, figsize=(14, 6))
# Out:
# <Axes: ylabel='Frequency'>

# %%
prem_data['HS'].plot(kind='box', vert=False, figsize=(14, 6))
# Out:
# <Axes: >

# %%
prem_data['HS'].value_counts()
# Out:
# HS
# 13    29
# 15    27
# 12    26
# 14    24
# 17    22
# 16    21
# 11    21
# 18    21
# 19    21
# 10    19
# 9     19
# 8     15
# 20    13
# 21    13
# 7     12
# 6     10
# 25    10
# 23     7
# 22     6
# 27     6
# 26     5
# 28     5
# 24     5
# 5      5
# 29     3
# 4      3
# 33     2
# 34     2
# 30     2
# 31     2
# 3      1
# 32     1
# 1      1
# 36     1
# Name: count, dtype: int64

# %%
prem_data['HS'].value_counts().plot(kind='pie', figsize=(14, 6))
# Out:
# <Axes: ylabel='count'>

# %%
prem_data['HC'].value_counts()
# Out:
# HC
# 4     58
# 6     45
# 8     41
# 7     40
# 3     38
# 5     32
# 10    22
# 9     22
# 2     20
# 1     18
# 12    14
# 11    14
# 0      6
# 15     3
# 13     3
# 14     2
# 17     1
# 16     1
# Name: count, dtype: int64

# %%
prem_data['HC'].value_counts().plot(kind='bar', figsize=(14, 6))
# Out:
# <Axes: xlabel='HC'>

# %%
prem_data['HC'].value_counts().head(1)
# Out:
# HC
# 4    58
# Name: count, dtype: int64

# %%
prem_data['HC'].value_counts().plot(kind='bar', figsize=(14, 6))
# Out:
# <Axes: xlabel='HC'>

# %%
prem_data['FTR'].value_counts()
# Out:
# FTR
# H    175
# A    123
# D     82
# Name: count, dtype: int64

# %%
prem_data['FTR'].value_counts().plot(kind='pie', figsize=(14, 6))
# Out:
# <Axes: ylabel='count'>

# %%
prem_data["FTR"].unique()
# Out:
# array(['A', 'H', 'D'], dtype=object)

# %%
prem_data['HC'].unique()
# Out:
# array([ 6,  8, 10,  5,  3,  4,  7,  1, 11, 17,  9, 12, 15,  2,  0, 13, 14,
#        16])

# %%
prem_data['HC'].value_counts().head(10).plot(kind='bar', figsize=(14, 6))
# Out:
# <Axes: xlabel='HC'>

# %%
prem_data.plot(kind='scatter', x='HST', y='FTHG', figsize=(14, 6))
# Out:
# <Axes: xlabel='HST', ylabel='FTHG'>

# %%
prem_data.plot(kind='scatter', x='HS', y='HC', figsize=(14, 6))
# Out:
# <Axes: xlabel='HS', ylabel='HC'>

# %%
prem_data[['HomeTeam', 'FTHG']].boxplot(by='HomeTeam', figsize=(20, 6))
# Out:
# <Axes: title={'center': 'FTHG'}, xlabel='[HomeTeam]'>

# %%
prem_data[['HomeTeam', 'FTAG']].boxplot(by='HomeTeam', figsize=(20, 6))
# Out:
# <Axes: title={'center': 'FTAG'}, xlabel='[HomeTeam]'>

# %%
prem_data[['HomeTeam', 'HS']].boxplot(by='HomeTeam', figsize=(20, 6))
# Out:
# <Axes: title={'center': 'HS'}, xlabel='[HomeTeam]'>

# %%
prem_data[['HomeTeam', 'AS']].boxplot(by='HomeTeam', figsize=(20, 6))
# Out:
# <Axes: title={'center': 'AS'}, xlabel='[HomeTeam]'>

# %%
prem_data['HFTS'] = prem_data[['FTHG', 'FTAG']].apply(lambda x: x[0] - x[1], axis=1)
prem_data['HFTS'].head()
# Out:
# /var/folders/q2/94833wl55_l8xcdswqrk28340000gn/T/ipykernel_8194/1956865324.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   prem_data['HFTS'] = prem_data[['FTHG', 'FTAG']].apply(lambda x: x[0] - x[1], axis=1)
# 0   -3
# 1    1
# 2    0
# 3    3
# 4   -1
# Name: HFTS, dtype: int64

# %%
prem_data['HC'].mean()
# Out:
# np.float64(6.123684210526315)

# %%
prem_data['HC'] += 2

prem_data['HC'].mean()
# Out:
# np.float64(8.123684210526315)

# %%
prem_data.loc[((prem_data['FTR'] == 'H') | (prem_data['FTR'] == 'D'))].shape[0]
# Out:
# 257

# %%
prem_data.loc[((prem_data['HomeTeam'] == 'Man United') & (prem_data['FTR'] == 'H')) | (prem_data['AwayTeam'] == 'Man United') & (prem_data['FTR'] == 'A')].shape[0]
# Out:
# 18
